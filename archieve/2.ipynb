# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df = pd.read_csv("dropped_shi.csv")
df
# Out:
#                    review_dttm              finish_dttm  \
# 0          2025-02-18 15:41:00  2025-02-18 16:56:49.353
# 1          2025-03-24 20:06:00  2025-03-28 17:42:39.772
# 2          2025-07-08 07:40:43  2025-07-08 10:29:04.740
# 3          2025-08-07 22:51:48  2025-08-08 09:35:34.593
# 4          2025-02-13 21:38:40  2025-02-14 08:04:44.643
# ...                        ...                      ...
# 56815  2025-05-23 18:29:43.000  2025-05-23 19:25:21.222
# 56816  2025-09-26 10:16:00.000  2025-09-26 13:27:02.360
# 56817  2025-10-23 18:41:00.000  2025-10-23 19:20:28.205
# 56818  2025-09-02 13:12:13.000  2025-09-02 13:35:01.523
# 56819  2025-10-27 22:18:00.000  2025-10-28 10:15:36.219
#
#                               id_client    company  review_mark  \
# 0      fb30834209a9c7f60612c64b82c75ffa       Банк            1
# 1      6601bfab426e4f56cc1e44d859683763  Страховая            1
# 2      f1f8eff66eaf2289f61deec744871d6b       Банк            5
# 3      5ca669878eaf593f68c10e163246357b        SME            5
# 4      7a436100b113ce78c8a7a02974521a16       Банк            5
# ...                                 ...        ...          ...
# 56815  19a90f722e0088dbd5c1140326475d4c  Страховая            5
# 56816  3e5ccb5ffa7055f82085ccd18b7190c4       Банк            5
# 56817  ff8dee14ae0b2c22593ab20ffb9d8e26       Банк            5
# 56818  b8deb649421f64fc4a5b6c71b350f528       Банк            5
# 56819  6733622ad6159491ff745804ebad2e49  Страховая            5
#
#        review_emotion review_source          business_line          product  \
# 0                   0      banki.ru        кредитные карты  кредитная карта
# 1                   0      banki.ru              страховая            каско
# 2                   1      banki.ru    депозитные продукты  дебетовая карта
# 3                   1      banki.ru                    sme   расчетный счет
# 4                   1      banki.ru    депозитные продукты  дебетовая карта
# ...               ...           ...                    ...              ...
# 56815               1      banki.ru              страховая              взр
# 56816               1     sravni.ru  поддержка сотрудников    не определено
# 56817               1     sravni.ru    депозитные продукты  дебетовая карта
# 56818               1      banki.ru    премиальные сервисы          premium
# 56819               1     sravni.ru              страховая              взр
#
#               reason                  review_theme  \
# 0      Не определено              тарифы и условия
# 1      Не определено             страховое событие
# 2      Не определено                мп/лк/терминал
# 3      Не определено         дополнительные услуги
# 4      Не определено                        кэшбек
# ...              ...                           ...
# 56815  Не определено             страховое событие
# 56816  Не определено              тарифы и условия
# 56817  Не определено                мп/лк/терминал
# 56818  Не определено  платежи, переводы и операции
# 56819  Не определено             страховое событие
#
#                                                subtheme  \
# 0                              консультация по продукту
# 1                           жалоба по страховому случаю
# 2                       установка/обновление приложения
# 3                                консультация по услуге
# 4                                 корректировка кэшбека
# ...                                                 ...
# 56815  консультации по существующему страховому событию
# 56816                          консультация по продукту
# 56817                        консультация по интерфейсу
# 56818                              отмена / оспаривание
# 56819  консультации по существующему страховому событию
#
#                                              review_text     solution_flg  \
# 0      Непрозрачные условия, скрытые комсисии. Почему...  проблема решена
# 1      Обратился по каско , влетел камень в лобовое с...  проблема решена
# 2      Я уже очень давно пользуюсь услугами Тбанка и ...       не указано
# 3      Уважаемое руководство Т- Банка,\n\n\nНастоящим...       не указано
# 4      Выбрал на текущий месяц повышенный кэшбек на к...       не указано
# ...                                                  ...              ...
# 56815  Отдыхали в новый год в Тель-Авиве с ребёнком. ...       не указано
# 56816  Здравствуйте я очень довольна работой группы п...       не указано
# 56817  Банк и прилодение\nПо моему мнению лучший банк...       не указано
# 56818  Огромная благодарность сотруднику Т-Банка (Лео...       не указано
# 56819  Добрый день.\n\n16.10.2025 Года совершал Авиап...       не указано
#
#       gender_cd  education_level_cd  marital_status_cd  children_cnt  \
# 0             M                 NaN                0.0           0.0
# 1             M                 NaN                NaN           0.0
# 2             M                 0.0                1.0           0.0
# 3             F                 0.0                1.0           0.0
# 4             M                 NaN                NaN           0.0
# ...         ...                 ...                ...           ...
# 56815         M                 NaN                2.0           0.0
# 56816         F                 0.0                4.0           0.0
# 56817         M                 NaN                1.0           0.0
# 56818         M                 NaN                NaN           0.0
# 56819         M                 NaN                0.0           0.0
#
#       citizenship_country           segment_name  subscription_important_flg  \
# 0                      РФ               Доходные                         0.0
# 1                      РФ                    NaN                         0.0
# 2                      РФ           Малодоходные                         0.0
# 3                      РФ  Высокодоходные без ПМ                         0.0
# 4                      РФ               Доходные                         0.0
# ...                   ...                    ...                         ...
# 56815                  РФ                    NaN                         0.0
# 56816                  РФ               Доходные                         0.0
# 56817                  РФ               Доходные                         0.0
# 56818                  РФ               Доходные                         0.0
# 56819                  РФ                    NaN                         0.0
#
#        new_flg  influencer_flg age_segment  csat_score  review_day  \
# 0          0.0             0.0    Молодежь         NaN  2025-02-18
# 1          0.0             0.0         NaN         NaN  2025-03-24
# 2          0.0             0.0    Взрослые         NaN  2025-07-08
# 3          0.0             1.0    Взрослые         NaN  2025-08-07
# 4          0.0             1.0     Сеньоры         NaN  2025-02-13
# ...        ...             ...         ...         ...         ...
# 56815      0.0             0.0         NaN         NaN  2025-05-23
# 56816      0.0             0.0     Сеньоры         NaN  2025-09-26
# 56817      0.0             0.0    Взрослые         NaN  2025-10-23
# 56818      0.0             1.0    Взрослые         NaN  2025-09-02
# 56819      0.0             0.0         NaN         NaN  2025-10-27
#
#       review_time  review_month  finish_day      finish_time  finish_month
# 0        15:41:00             2  2025-02-18  16:56:49.353000           2.0
# 1        20:06:00             3  2025-03-28  17:42:39.772000           3.0
# 2        07:40:43             7  2025-07-08  10:29:04.740000           7.0
# 3        22:51:48             8  2025-08-08  09:35:34.593000           8.0
# 4        21:38:40             2  2025-02-14  08:04:44.643000           2.0
# ...           ...           ...         ...              ...           ...
# 56815    18:29:43             5  2025-05-23  19:25:21.222000           5.0
# 56816    10:16:00             9  2025-09-26  13:27:02.360000           9.0
# 56817    18:41:00            10  2025-10-23  19:20:28.205000          10.0
# 56818    13:12:13             9  2025-09-02  13:35:01.523000           9.0
# 56819    22:18:00            10  2025-10-28  10:15:36.219000          10.0
#
# [56820 rows x 31 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df["hours_of_review"] = (df.finish_dttm - df.review_dttm).dt.total_seconds / 3600
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:6154, in Series._arith_method(self, other, op)
#    6152 def _arith_method(self, other, op):
#    6153     self, other = self._align_for_op(other)
# -> 6154     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
